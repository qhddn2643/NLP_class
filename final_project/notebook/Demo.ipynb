# %%
from transformers import PreTrainedTokenizerFast, MT5ForConditionalGeneration

source_tokenizer = PreTrainedTokenizerFast.from_pretrained("../da_en_output_dir/da_tokenizer")
target_tokenizer = PreTrainedTokenizerFast.from_pretrained("../da_en_output_dir/en_tokenizer")

model = MT5ForConditionalGeneration.from_pretrained("../da_en_output_dir/")
model.eval()
# Out:
# MT5ForConditionalGeneration(
#   (shared): Embedding(250102, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(250102, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=384, bias=False)
#               (k): Linear(in_features=512, out_features=384, bias=False)
#               (v): Linear(in_features=512, out_features=384, bias=False)
#               (o): Linear(in_features=384, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 6)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedGeluDense(
#               (wi_0): Linear(in_features=512, out_features=1024, bias=False)
# ...

# %%
input_ids = source_tokenizer.encode("Hello, my name is Bongwoo", return_tensors="pt")
target_tokenizer.decode(input_ids[0])
# Out:
# 'EnrichedAccount OM, ho 12 ame B Recurring o'

# %%
import datasets
datasets = datasets.load_dataset("code_x_glue_tt_text_to_text", "da_en")
datasets
# Out:
# Reusing dataset code_x_glue_tt_text_to_text (/home/qhddn2643/.cache/huggingface/datasets/code_x_glue_tt_text_to_text/da_en/0.0.0/eef07f49359a4a30ef8f3fe6802a25f7ef9603e35c54b63235e15bdbdcbfea87)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'source', 'target'],
#         num_rows: 42701
#     })
#     validation: Dataset({
#         features: ['id', 'source', 'target'],
#         num_rows: 1000
#     })
#     test: Dataset({
#         features: ['id', 'source', 'target'],
#         num_rows: 1000
#     })
# })
